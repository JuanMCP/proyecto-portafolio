# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
data= pd.read_csv('C:\\Users\\jjcpm3\\Documents\\GitHub\\proyecto-portafolio\\data\\Data Science Salary\\ds_salaries_sdup.csv')
data
# Out:
#       work_year experience_level employment_type                job_title  \
# 0          2021               MI              FT           Data Scientist
# 1          2021               MI              FT            Data Engineer
# 2          2021               EN              FT           Data Scientist
# 3          2022               MI              FT             NLP Engineer
# 4          2021               EN              FT       Power BI Developer
# ...         ...              ...             ...                      ...
# 2663       2023               SE              FT             AI Scientist
# 2664       2022               MI              FT             Data Analyst
# 2665       2020               MI              FT       Research Scientist
# 2666       2021               MI              FT   Financial Data Analyst
# 2667       2021               EX              FT  Principal Data Engineer
#
#        salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0       58000             MXN           2859                 MX             0
# 1        4000             USD           4000                 IR           100
# 2        4000             USD           4000                 VN             0
# 3      120000             CZK           5132                 CZ           100
# 4      400000             INR           5409                 IN            50
# ...       ...             ...            ...                ...           ...
# 2663  1500000             ILS         423834                 IL             0
# 2664   350000             GBP         430967                 GB             0
# 2665   450000             USD         450000                 US             0
# 2666   450000             USD         450000                 US           100
# 2667   600000             USD         600000                 US           100
#
#      company_location company_size
# 0                  MX            S
# 1                  IR            M
# 2                  VN            M
# 3                  CZ            M
# 4                  IN            L
# ...               ...          ...
# 2663               IL            L
# 2664               GB            M
# 2665               US            M
# 2666               US            L
# 2667               US            L
#
# [2668 rows x 11 columns]

# %%
def get_summary(dataset):
    print("\nDimensions of dataset \n\n", dataset.shape)  
    print("\n\nSummary of dataset \n\n", dataset.describe())    
    print("\n\nDatatypes \n\n", dataset.dtypes)
    print("\n\nDataset glimpse \n")
    return(dataset.head(5))

get_summary(data)
# Out:
# Dimensions of dataset
#
#  (2668, 12)
#
#
# Summary of dataset
#
#           work_year        salary  salary_in_usd  remote_ratio
# count  2668.000000  2.668000e+03    2668.000000   2668.000000
# mean   2022.285607  2.106167e+05  131887.354198     50.899550
# std       0.747039  8.052707e+05   68133.796951     48.129002
# min    2020.000000  4.000000e+03    2859.000000      0.000000
# 25%    2022.000000  8.500000e+04   81375.000000      0.000000
# 50%    2022.000000  1.320000e+05  127344.000000     50.000000
# 75%    2023.000000  1.800450e+05  175000.000000    100.000000
# max    2023.000000  3.040000e+07  600000.000000    100.000000
#
#
# Datatypes
#
#  work_year              int64
# experience_level      object
# employment_type       object
# job_title             object
# salary                 int64
# salary_currency       object
# salary_in_usd          int64
# employee_residence    object
# remote_ratio           int64
# company_location      object
# company_size          object
# categoria             object
# dtype: object
#
#
# Dataset glimpse
#    work_year experience_level employment_type           job_title  salary  \
# 0       2021               MI              FT      Data Scientist   58000
# 1       2021               MI              FT       Data Engineer    4000
# 2       2021               EN              FT      Data Scientist    4000
# 3       2022               MI              FT        NLP Engineer  120000
# 4       2021               EN              FT  Power BI Developer  400000
#
#   salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0             MXN           2859                 MX             0
# 1             USD           4000                 IR           100
# 2             USD           4000                 VN             0
# 3             CZK           5132                 CZ           100
# 4             INR           5409                 IN            50
#
#   company_location company_size       categoria
# 0               MX            S  Data Scientist
# 1               IR            M   Data Engineer
# 2               VN            M  Data Scientist
# 3               CZ            M            Otro
# 4               IN            L            Otro

# %%
# Obtener todas las variables únicas en la columna "company_location"
unique_locations = data['company_location'].unique()

# Imprimir las variables únicas
print(unique_locations)
# Out:
# ['MX' 'IR' 'VN' 'CZ' 'IN' 'US' 'CH' 'BR' 'MK' 'GH' 'BO' 'SG' 'PK' 'KE'
#  'MA' 'AL' 'TR' 'LU' 'NG' 'ES' 'AR' 'SK' 'GR' 'UA' 'CA' 'TH' 'ID' 'DE'
#  'HU' 'MD' 'AS' 'DK' 'FR' 'HN' 'PT' 'IT' 'CO' 'EG' 'SI' 'MT' 'PL' 'GB'
#  'EE' 'LV' 'AU' 'MY' 'CL' 'JP' 'NL' 'CF' 'CN' 'BS' 'HR' 'AM' 'CR' 'PH'
#  'AT' 'BE' 'RO' 'FI' 'AE' 'HK' 'IE' 'LT' 'SE' 'RU' 'DZ' 'IQ' 'IL' 'BA'
#  'NZ' 'PR']

# %%
# Obtener todas las variables únicas en la columna "remote_ratio"
remote_ratio = data['remote_ratio'].unique()

# Imprimir las variables únicas
print(remote_ratio)
# Out:
# [  0 100  50]

# %%
# Obtener todas las variables únicas en la columna "employee_residence"
employee_residence = data['employee_residence'].unique()

# Imprimir las variables únicas
print(employee_residence)
# Out:
# ['MX' 'IR' 'VN' 'CZ' 'IN' 'BR' 'MK' 'FR' 'GH' 'BO' 'PK' 'KE' 'MA' 'CA'
#  'TR' 'PT' 'NG' 'ES' 'AR' 'SK' 'GR' 'UA' 'TH' 'ID' 'DE' 'HU' 'PL' 'MD'
#  'DK' 'AS' 'CR' 'HN' 'IT' 'CO' 'EG' 'US' 'SI' 'RS' 'RO' 'MT' 'GB' 'TN'
#  'EE' 'LV' 'AU' 'JP' 'CL' 'NL' 'CF' 'CN' 'HR' 'PH' 'RU' 'KW' 'AM' 'BE'
#  'AT' 'CH' 'LU' 'FI' 'CY' 'AE' 'HK' 'SG' 'IE' 'LT' 'SE' 'BG' 'UZ' 'DZ'
#  'IQ' 'JE' 'DO' 'BA' 'NZ' 'PR' 'MY' 'IL']

# %%
# Obtener todas las variables únicas en la columna "employment_type	"
employment_type	 = data['employment_type'].unique()

# Imprimir las variables únicas
print(employment_type)
# Out:
# ['FT' 'PT' 'CT' 'FL']

# %%
# Obtener todas las variables únicas en la columna "experience_level"
experience_level = data['experience_level'].unique()

# Imprimir las variables únicas
print(experience_level)
# Out:
# ['MI' 'EN' 'SE' 'EX']

# %% [raw]
# Primera Pregunta: ¿Cuál es la diferencia salarial en las distintas áreas de profesiones relacionadas con la ciencia de datos?

# %%
# Agrupar los salarios por título de trabajo y calcular la mediana
median_salaries = data.groupby('job_title')['salary_in_usd'].median()

# Ordenar los títulos de trabajo por la mediana de los salarios
sorted_titles = median_salaries.sort_values(ascending=False).index

# Crear el gráfico de barras o box plot
plt.figure(figsize=(12, 6))
plt.bar(sorted_titles, median_salaries[sorted_titles])
plt.xlabel('Job Title')
plt.ylabel('Median Salary (USD)')
plt.title('Median Salary by Job Title')
plt.xticks(rotation=45)
plt.show()

# %%
# Lista de categorías seleccionadas
categorias = ['Data Scientist', 'Data Engineer', 'Data Analyst', 'Machine Learning Engineer']

# Función para agrupar los títulos de trabajo en las categorías seleccionadas
def agrupar_titulo(titulo):
    for categoria in categorias:
        if categoria.lower() in titulo.lower():
            return categoria
    return 'Otro'

# Aplicar la función de agrupación a la columna 'job_title'
data['categoria'] = data['job_title'].apply(agrupar_titulo)

# %%
# Contar la cantidad de empleos en cada categoría
empleos_por_categoria = data['categoria'].value_counts()

# Agregar la categoría "Otro" con una cantidad específica
empleos_por_categoria['Otro'] = data['categoria'].value_counts().sum() - empleos_por_categoria.sum()

# Crear el gráfico de barras
plt.bar(empleos_por_categoria.index, empleos_por_categoria.values)
plt.xlabel('Categoría de empleo')
plt.ylabel('Cantidad de empleos')
plt.title('Distribución de empleos en el área de Big Data')
plt.xticks(rotation=45)

# Mostrar el gráfico
plt.show()

# %%
# Contar la cantidad de empleos en cada categoría
empleos_por_categoria = data['categoria'].value_counts()

# Crear el gráfico de barras
plt.bar(empleos_por_categoria.index, empleos_por_categoria.values)
plt.xlabel('Categoría de empleo')
plt.ylabel('Cantidad de empleos')
plt.title('Distribución de empleos en el área de Big Data')
plt.xticks(rotation=45)

# Mostrar el gráfico
plt.show()

# %% [raw]
# Segunda pregunta: ¿Existe una diferencia significativa entre los salarios de empleos a tiempo completo, medio tiempo y por contratos?

# %%
# Filtrar los datos por cada tipo de empleo
full_time_salaries = data[data['employment_type'] == 'FT']['salary_in_usd']
part_time_salaries = data[data['employment_type'] == 'PT']['salary_in_usd']
flexible_salaries = data[data['employment_type'] == 'FL']['salary_in_usd']
internship_salaries = data[data['employment_type'] == 'CT']['salary_in_usd']

# Calcular medidas estadísticas
mean_salaries = [full_time_salaries.mean(), part_time_salaries.mean(), flexible_salaries.mean(), internship_salaries.mean()]
median_salaries = [full_time_salaries.median(), part_time_salaries.median(), flexible_salaries.median(), internship_salaries.median()]
std_salaries = [full_time_salaries.std(), part_time_salaries.std(), flexible_salaries.std(), internship_salaries.std()]

# Crear el gráfico de barras
employment_types = ['Full-Time', 'Part-Time', 'Flexible', 'Internship']
plt.bar(employment_types, mean_salaries)
plt.xlabel('Employment Type')
plt.ylabel('Mean Salary (USD)')
plt.title('Mean Salary by Employment Type')
plt.show()

# Crear el boxplot
data.boxplot(column='salary_in_usd', by='employment_type')
plt.xlabel('Employment Type')
plt.ylabel('Salary (USD)')
plt.title('Salary Distribution by Employment Type')
plt.show()

# %% [raw]
# Pregunta 3:¿Cuáles son las diferencias salariales entre trabajar de forma remota, en una oficina o en un entorno híbrido?

# %%
# Cálculo de la media de los salarios para cada categoría de trabajo remoto
mean_salary_remote = data[data['remote_ratio'] == 100]['salary_in_usd'].mean()
mean_salary_hybrid = data[data['remote_ratio'] == 50]['salary_in_usd'].mean()
mean_salary_office = data[data['remote_ratio'] == 0]['salary_in_usd'].mean()

# Creación de las etiquetas y los valores para el gráfico
categories = ['Trabajo remoto', 'Entorno híbrido', 'Trabajo en oficina']
salaries = [mean_salary_remote, mean_salary_hybrid, mean_salary_office]

# Gráfico de barras de las diferencias salariales
plt.bar(categories, salaries)
plt.ylabel('Salario promedio (USD)')
plt.title('Diferencias salariales entre trabajo remoto, entorno híbrido y trabajo en oficina')
plt.show()

# %% [raw]
# Pregunta 4: ¿Cómo han evolucionado los salarios en el campo de los datos desde 2019?

# %%
# Filtrar los datos para incluir registros desde 2019 en adelante
data_2019_onwards = data[data['work_year'] >= 2019]

# Calcular la media de los salarios para cada año
mean_salaries_by_year = data_2019_onwards.groupby('work_year')['salary_in_usd'].mean()

# Obtener los años y los salarios promedio como listas
years = mean_salaries_by_year.index.tolist()
salaries = mean_salaries_by_year.values.tolist()

# Gráfico de líneas para visualizar la evolución de los salarios
plt.plot(years, salaries, marker='o')
plt.xlabel('Año')
plt.ylabel('Salario promedio (USD)')
plt.title('Evolución de los salarios en el campo de los datos desde 2019')
plt.xticks(years)
plt.show()

# %%
# Boxplot por año
sns.boxplot(x='work_year', y='salary_in_usd', data=data)
plt.xlabel('Año')
plt.ylabel('Salario en USD')
plt.title('Boxplot de Salarios por Año')
plt.show()

# %%
import numpy as np
from sklearn.linear_model import LinearRegression

# Obtener los años y salarios promedio
years = np.unique(data['work_year'])
mean_salary_by_year = data.groupby('work_year')['salary_in_usd'].mean()

# Crear un arreglo de años consecutivos que incluya el año 2024
years_extended = np.append(years, 2024)

# Reshape los años para que tengan la forma adecuada para el modelo
X = years.reshape(-1, 1)
X_extended = years_extended.reshape(-1, 1)

# Crear el modelo de regresión lineal y ajustarlo a los datos
regression = LinearRegression()
regression.fit(X, mean_salary_by_year)

# Calcular la estimación para el año 2024
predicted_salary_2024 = regression.predict([[2024]])[0]

# Redondear el resultado a dos decimales
predicted_salary_2024 = round(predicted_salary_2024, 2)

# Visualizar la tendencia y la estimación para el año 2024
plt.plot(years, mean_salary_by_year, marker='o', label='Datos históricos')
plt.plot(2024, predicted_salary_2024, marker='o', color='red', label='Estimación 2024')
plt.xlabel('Año')
plt.ylabel('Salario promedio en USD')
plt.title('Tendencia de Salarios por Año')
plt.legend()
plt.show()

print(f"La estimación del salario promedio para el año 2024 es: {predicted_salary_2024:.2f} USD")
# Out:
# La estimación del salario promedio para el año 2024 es: 164308.68 USD

# %% [raw]
# pregunta 5:¿Cuál es la distribución geográfica de las compañías que ofrecen trabajos en el campo de la ciencia de datos, y cuál es el tipo de empleo predominante (trabajo remoto, híbrido o presencial) en cada ubicación?

# %%
# Obtener la distribución de las ubicaciones de las compañías
company_location_counts = data['company_location'].value_counts()

# Visualizar la distribución de ubicaciones de compañías
plt.figure(figsize=(10, 6))
company_location_counts.plot(kind='bar')
plt.xlabel('Ubicación de Compañía')
plt.ylabel('Frecuencia')
plt.title('Distribución de Ubicaciones de Compañías')
plt.xticks(rotation=45)
plt.show()

# Determinar el tipo de trabajo predominante en cada ubicación
locations = data['company_location'].unique()

for location in locations:
    location_data = data[data['company_location'] == location]
    employment_type_counts = location_data['employment_type'].value_counts()
    predominant_employment_type = employment_type_counts.idxmax()
    print(f"En {location}, el tipo de trabajo predominante es: {predominant_employment_type}")
# Out:
# En MX, el tipo de trabajo predominante es: FT
# En IR, el tipo de trabajo predominante es: FT
# En VN, el tipo de trabajo predominante es: FT
# En CZ, el tipo de trabajo predominante es: FT
# En IN, el tipo de trabajo predominante es: FT
# En US, el tipo de trabajo predominante es: FT
# En CH, el tipo de trabajo predominante es: FT
# En BR, el tipo de trabajo predominante es: FT
# En MK, el tipo de trabajo predominante es: FT
# En GH, el tipo de trabajo predominante es: FT
# En BO, el tipo de trabajo predominante es: CT
# En SG, el tipo de trabajo predominante es: FT
# En PK, el tipo de trabajo predominante es: FT
# En KE, el tipo de trabajo predominante es: FT
# En MA, el tipo de trabajo predominante es: FT
# En AL, el tipo de trabajo predominante es: FT
# En TR, el tipo de trabajo predominante es: FT
# En LU, el tipo de trabajo predominante es: FT
# En NG, el tipo de trabajo predominante es: FT
# En ES, el tipo de trabajo predominante es: FT
# En AR, el tipo de trabajo predominante es: FT
# En SK, el tipo de trabajo predominante es: FT
# En GR, el tipo de trabajo predominante es: FT
# En UA, el tipo de trabajo predominante es: FT
# En CA, el tipo de trabajo predominante es: FT
# En TH, el tipo de trabajo predominante es: FT
# En ID, el tipo de trabajo predominante es: FT
# En DE, el tipo de trabajo predominante es: FT
# En HU, el tipo de trabajo predominante es: FT
# En MD, el tipo de trabajo predominante es: FT
# En AS, el tipo de trabajo predominante es: FT
# En DK, el tipo de trabajo predominante es: PT
# En FR, el tipo de trabajo predominante es: FT
# En HN, el tipo de trabajo predominante es: FT
# En PT, el tipo de trabajo predominante es: FT
# En IT, el tipo de trabajo predominante es: FT
# En CO, el tipo de trabajo predominante es: FT
# En EG, el tipo de trabajo predominante es: FT
# En SI, el tipo de trabajo predominante es: FT
# En MT, el tipo de trabajo predominante es: FT
# En PL, el tipo de trabajo predominante es: FT
# En GB, el tipo de trabajo predominante es: FT
# En EE, el tipo de trabajo predominante es: FT
# En LV, el tipo de trabajo predominante es: FT
# En AU, el tipo de trabajo predominante es: FT
# En MY, el tipo de trabajo predominante es: FT
# En CL, el tipo de trabajo predominante es: FT
# En JP, el tipo de trabajo predominante es: FT
# En NL, el tipo de trabajo predominante es: FT
# En CF, el tipo de trabajo predominante es: FT
# En CN, el tipo de trabajo predominante es: FT
# En BS, el tipo de trabajo predominante es: FL
# En HR, el tipo de trabajo predominante es: FT
# En AM, el tipo de trabajo predominante es: FT
# En CR, el tipo de trabajo predominante es: FT
# En PH, el tipo de trabajo predominante es: FT
# En AT, el tipo de trabajo predominante es: FT
# En BE, el tipo de trabajo predominante es: FT
# En RO, el tipo de trabajo predominante es: FT
# En FI, el tipo de trabajo predominante es: FT
# En AE, el tipo de trabajo predominante es: FT
# En HK, el tipo de trabajo predominante es: FT
# En IE, el tipo de trabajo predominante es: FT
# En LT, el tipo de trabajo predominante es: FT
# En SE, el tipo de trabajo predominante es: FT
# En RU, el tipo de trabajo predominante es: FT
# En DZ, el tipo de trabajo predominante es: PT
# En IQ, el tipo de trabajo predominante es: FT
# En IL, el tipo de trabajo predominante es: FT
# En BA, el tipo de trabajo predominante es: FT
# En NZ, el tipo de trabajo predominante es: FT
# En PR, el tipo de trabajo predominante es: FT
