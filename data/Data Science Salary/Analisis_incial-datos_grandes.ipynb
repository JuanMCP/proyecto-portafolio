# %%
import pandas as pd

# %%
pd.read_csv('E:\Github Desktop\proyecto-portafolio\data\Data Science Salary\ds_salaries.csv')
# Out:
#       work_year experience_level employment_type                 job_title  \
# 0          2023               SE              FT  Principal Data Scientist
# 1          2023               MI              CT               ML Engineer
# 2          2023               MI              CT               ML Engineer
# 3          2023               SE              FT            Data Scientist
# 4          2023               SE              FT            Data Scientist
# ...         ...              ...             ...                       ...
# 3750       2020               SE              FT            Data Scientist
# 3751       2021               MI              FT  Principal Data Scientist
# 3752       2020               EN              FT            Data Scientist
# 3753       2020               EN              CT     Business Data Analyst
# 3754       2021               SE              FT      Data Science Manager
#
#        salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0       80000             EUR          85847                 ES           100
# 1       30000             USD          30000                 US           100
# 2       25500             USD          25500                 US           100
# 3      175000             USD         175000                 CA           100
# 4      120000             USD         120000                 CA           100
# ...       ...             ...            ...                ...           ...
# 3750   412000             USD         412000                 US           100
# 3751   151000             USD         151000                 US           100
# 3752   105000             USD         105000                 US           100
# 3753   100000             USD         100000                 US           100
# 3754  7000000             INR          94665                 IN            50
#
#      company_location company_size
# 0                  ES            L
# 1                  US            S
# 2                  US            S
# 3                  CA            M
# 4                  CA            M
# ...               ...          ...
# 3750               US            L
# 3751               US            L
# 3752               US            S
# 3753               US            L
# 3754               IN            L
#
# [3755 rows x 11 columns]

# %%
pip install -U dataprep
# Out:
# Collecting dataprepNote: you may need to restart the kernel to use updated packages.
#
#   Downloading dataprep-0.4.5-py3-none-any.whl (9.9 MB)
#      ---------------------------------------- 9.9/9.9 MB 3.3 MB/s eta 0:00:00
# Requirement already satisfied: pandas<2.0,>=1.1 in e:\anaconda\anaconda de nuevo\lib\site-packages (from dataprep) (1.5.3)
# Collecting metaphone<0.7,>=0.6
#   Downloading Metaphone-0.6.tar.gz (14 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: nltk<4.0.0,>=3.6.7 in e:\anaconda\anaconda de nuevo\lib\site-packages (from dataprep) (3.7)
# Collecting varname<0.9.0,>=0.8.1
#   Downloading varname-0.8.3-py3-none-any.whl (21 kB)
# Collecting python-stdnum<2.0,>=1.16
#   Downloading python_stdnum-1.18-py2.py3-none-any.whl (1.0 MB)
#      ---------------------------------------- 1.0/1.0 MB 3.0 MB/s eta 0:00:00
# Collecting wordcloud<2.0,>=1.8
#   Downloading wordcloud-1.9.2-cp310-cp310-win_amd64.whl (152 kB)
#      -------------------------------------- 152.1/152.1 kB 4.6 MB/s eta 0:00:00
# Collecting aiohttp<4.0,>=3.6
#   Downloading aiohttp-3.8.4-cp310-cp310-win_amd64.whl (319 kB)
#      -------------------------------------- 319.8/319.8 kB 3.3 MB/s eta 0:00:00
# Requirement already satisfied: scipy<2.0,>=1.8 in e:\anaconda\anaconda de nuevo\lib\site-packages (from dataprep) (1.10.0)
# Collecting sqlalchemy==1.3.24
#   Downloading SQLAlchemy-1.3.24.tar.gz (6.4 MB)
#      ---------------------------------------- 6.4/6.4 MB 3.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting regex<2022.0.0,>=2021.8.3
#   Downloading regex-2021.11.10-cp310-cp310-win_amd64.whl (273 kB)
#      -------------------------------------- 273.3/273.3 kB 4.2 MB/s eta 0:00:00
# Collecting jinja2<3.1,>=3.0
#   Downloading Jinja2-3.0.3-py3-none-any.whl (133 kB)
#      -------------------------------------- 133.6/133.6 kB 4.0 MB/s eta 0:00:00
# Collecting pydot<2.0.0,>=1.4.2
#   Downloading pydot-1.4.2-py2.py3-none-any.whl (21 kB)
# Requirement already satisfied: flask<3,>=2 in e:\anaconda\anaconda de nuevo\lib\site-packages (from dataprep) (2.2.2)
# Requirement already satisfied: numpy<2.0,>=1.21 in e:\anaconda\anaconda de nuevo\lib\site-packages (from dataprep) (1.23.5)
# Collecting jsonpath-ng<2.0,>=1.5
#   Downloading jsonpath_ng-1.5.3-py3-none-any.whl (29 kB)
# Collecting python-crfsuite==0.9.8
#   Downloading python_crfsuite-0.9.8-cp310-cp310-win_amd64.whl (158 kB)
#      -------------------------------------- 158.9/158.9 kB 3.2 MB/s eta 0:00:00
# Collecting pydantic<2.0,>=1.6
#   Downloading pydantic-1.10.9-cp310-cp310-win_amd64.whl (2.1 MB)
#      ---------------------------------------- 2.1/2.1 MB 3.5 MB/s eta 0:00:00
# Requirement already satisfied: bokeh<3,>=2 in e:\anaconda\anaconda de nuevo\lib\site-packages (from dataprep) (2.4.3)
# Collecting flask_cors<4.0.0,>=3.0.10
#   Downloading Flask_Cors-3.0.10-py2.py3-none-any.whl (14 kB)
# Collecting rapidfuzz<3.0.0,>=2.1.2
#   Downloading rapidfuzz-2.15.1-cp310-cp310-win_amd64.whl (1.8 MB)
#      ---------------------------------------- 1.8/1.8 MB 3.5 MB/s eta 0:00:00
# Requirement already satisfied: tqdm<5.0,>=4.48 in e:\anaconda\anaconda de nuevo\lib\site-packages (from dataprep) (4.64.1)
# Requirement already satisfied: ipywidgets<8.0,>=7.5 in e:\anaconda\anaconda de nuevo\lib\site-packages (from dataprep) (7.6.5)
# Requirement already satisfied: dask[array,dataframe,delayed]>=2022.3.0 in e:\anaconda\anaconda de nuevo\lib\site-packages (from dataprep) (2022.7.0)
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Requirement already satisfied: attrs>=17.3.0 in e:\anaconda\anaconda de nuevo\lib\site-packages (from aiohttp<4.0,>=3.6->dataprep) (22.1.0)
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.3.3-cp310-cp310-win_amd64.whl (33 kB)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in e:\anaconda\anaconda de nuevo\lib\site-packages (from aiohttp<4.0,>=3.6->dataprep) (2.0.4)
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.4-cp310-cp310-win_amd64.whl (28 kB)
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.9.2-cp310-cp310-win_amd64.whl (61 kB)
#      ---------------------------------------- 61.0/61.0 kB 3.2 MB/s eta 0:00:00
# Requirement already satisfied: pillow>=7.1.0 in e:\anaconda\anaconda de nuevo\lib\site-packages (from bokeh<3,>=2->dataprep) (9.4.0)
# Requirement already satisfied: PyYAML>=3.10 in e:\anaconda\anaconda de nuevo\lib\site-packages (from bokeh<3,>=2->dataprep) (6.0)
# Requirement already satisfied: tornado>=5.1 in c:\users\user\appdata\roaming\python\python310\site-packages (from bokeh<3,>=2->dataprep) (6.2)
# Requirement already satisfied: packaging>=16.8 in c:\users\user\appdata\roaming\python\python310\site-packages (from bokeh<3,>=2->dataprep) (21.3)
# Requirement already satisfied: typing-extensions>=3.10.0 in e:\anaconda\anaconda de nuevo\lib\site-packages (from bokeh<3,>=2->dataprep) (4.4.0)
# Requirement already satisfied: partd>=0.3.10 in e:\anaconda\anaconda de nuevo\lib\site-packages (from dask[array,dataframe,delayed]>=2022.3.0->dataprep) (1.2.0)
# Requirement already satisfied: toolz>=0.8.2 in e:\anaconda\anaconda de nuevo\lib\site-packages (from dask[array,dataframe,delayed]>=2022.3.0->dataprep) (0.12.0)
# Requirement already satisfied: cloudpickle>=1.1.1 in e:\anaconda\anaconda de nuevo\lib\site-packages (from dask[array,dataframe,delayed]>=2022.3.0->dataprep) (2.0.0)
# Requirement already satisfied: fsspec>=0.6.0 in e:\anaconda\anaconda de nuevo\lib\site-packages (from dask[array,dataframe,delayed]>=2022.3.0->dataprep) (2022.11.0)
# Requirement already satisfied: itsdangerous>=2.0 in e:\anaconda\anaconda de nuevo\lib\site-packages (from flask<3,>=2->dataprep) (2.0.1)
# Requirement already satisfied: Werkzeug>=2.2.2 in e:\anaconda\anaconda de nuevo\lib\site-packages (from flask<3,>=2->dataprep) (2.2.2)
# Requirement already satisfied: click>=8.0 in e:\anaconda\anaconda de nuevo\lib\site-packages (from flask<3,>=2->dataprep) (8.0.4)
# Requirement already satisfied: Six in c:\users\user\appdata\roaming\python\python310\site-packages (from flask_cors<4.0.0,>=3.0.10->dataprep) (1.16.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in e:\anaconda\anaconda de nuevo\lib\site-packages (from ipywidgets<8.0,>=7.5->dataprep) (3.5.2)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\user\appdata\roaming\python\python310\site-packages (from ipywidgets<8.0,>=7.5->dataprep) (5.4.0)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\user\appdata\roaming\python\python310\site-packages (from ipywidgets<8.0,>=7.5->dataprep) (6.15.3)
# Requirement already satisfied: ipython>=4.0.0 in c:\users\user\appdata\roaming\python\python310\site-packages (from ipywidgets<8.0,>=7.5->dataprep) (8.5.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in e:\anaconda\anaconda de nuevo\lib\site-packages (from ipywidgets<8.0,>=7.5->dataprep) (1.0.0)
# Requirement already satisfied: nbformat>=4.2.0 in e:\anaconda\anaconda de nuevo\lib\site-packages (from ipywidgets<8.0,>=7.5->dataprep) (5.7.0)
# Requirement already satisfied: ipython-genutils~=0.2.0 in e:\anaconda\anaconda de nuevo\lib\site-packages (from ipywidgets<8.0,>=7.5->dataprep) (0.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in e:\anaconda\anaconda de nuevo\lib\site-packages (from jinja2<3.1,>=3.0->dataprep) (2.1.1)
# Requirement already satisfied: decorator in c:\users\user\appdata\roaming\python\python310\site-packages (from jsonpath-ng<2.0,>=1.5->dataprep) (5.1.1)
# Requirement already satisfied: ply in e:\anaconda\anaconda de nuevo\lib\site-packages (from jsonpath-ng<2.0,>=1.5->dataprep) (3.11)
# Requirement already satisfied: joblib in e:\anaconda\anaconda de nuevo\lib\site-packages (from nltk<4.0.0,>=3.6.7->dataprep) (1.1.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\user\appdata\roaming\python\python310\site-packages (from pandas<2.0,>=1.1->dataprep) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in e:\anaconda\anaconda de nuevo\lib\site-packages (from pandas<2.0,>=1.1->dataprep) (2022.7)
# Requirement already satisfied: pyparsing>=2.1.4 in c:\users\user\appdata\roaming\python\python310\site-packages (from pydot<2.0.0,>=1.4.2->dataprep) (3.0.9)
# Requirement already satisfied: colorama in c:\users\user\appdata\roaming\python\python310\site-packages (from tqdm<5.0,>=4.48->dataprep) (0.4.5)
# Requirement already satisfied: pure_eval<1.0.0 in c:\users\user\appdata\roaming\python\python310\site-packages (from varname<0.9.0,>=0.8.1->dataprep) (0.2.2)
# Requirement already satisfied: asttokens<3.0.0,>=2.0.0 in c:\users\user\appdata\roaming\python\python310\site-packages (from varname<0.9.0,>=0.8.1->dataprep) (2.0.8)
# Collecting executing<0.9.0,>=0.8.3
#   Downloading executing-0.8.3-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: matplotlib in e:\anaconda\anaconda de nuevo\lib\site-packages (from wordcloud<2.0,>=1.8->dataprep) (3.7.0)
# Requirement already satisfied: nest-asyncio in c:\users\user\appdata\roaming\python\python310\site-packages (from ipykernel>=4.5.1->ipywidgets<8.0,>=7.5->dataprep) (1.5.5)
# Requirement already satisfied: pyzmq>=17 in c:\users\user\appdata\roaming\python\python310\site-packages (from ipykernel>=4.5.1->ipywidgets<8.0,>=7.5->dataprep) (24.0.1)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\user\appdata\roaming\python\python310\site-packages (from ipykernel>=4.5.1->ipywidgets<8.0,>=7.5->dataprep) (7.3.5)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\user\appdata\roaming\python\python310\site-packages (from ipykernel>=4.5.1->ipywidgets<8.0,>=7.5->dataprep) (0.1.6)
# Requirement already satisfied: debugpy>=1.0 in c:\users\user\appdata\roaming\python\python310\site-packages (from ipykernel>=4.5.1->ipywidgets<8.0,>=7.5->dataprep) (1.6.3)
# Requirement already satisfied: psutil in c:\users\user\appdata\roaming\python\python310\site-packages (from ipykernel>=4.5.1->ipywidgets<8.0,>=7.5->dataprep) (5.9.2)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\user\appdata\roaming\python\python310\site-packages (from ipython>=4.0.0->ipywidgets<8.0,>=7.5->dataprep) (2.13.0)
# Requirement already satisfied: prompt-toolkit<3.1.0,>3.0.1 in c:\users\user\appdata\roaming\python\python310\site-packages (from ipython>=4.0.0->ipywidgets<8.0,>=7.5->dataprep) (3.0.31)
# Requirement already satisfied: backcall in c:\users\user\appdata\roaming\python\python310\site-packages (from ipython>=4.0.0->ipywidgets<8.0,>=7.5->dataprep) (0.2.0)
# Requirement already satisfied: pickleshare in c:\users\user\appdata\roaming\python\python310\site-packages (from ipython>=4.0.0->ipywidgets<8.0,>=7.5->dataprep) (0.7.5)
# Requirement already satisfied: jedi>=0.16 in c:\users\user\appdata\roaming\python\python310\site-packages (from ipython>=4.0.0->ipywidgets<8.0,>=7.5->dataprep) (0.18.1)
# Requirement already satisfied: stack-data in c:\users\user\appdata\roaming\python\python310\site-packages (from ipython>=4.0.0->ipywidgets<8.0,>=7.5->dataprep) (0.5.0)
# Requirement already satisfied: fastjsonschema in e:\anaconda\anaconda de nuevo\lib\site-packages (from nbformat>=4.2.0->ipywidgets<8.0,>=7.5->dataprep) (2.16.2)
# Requirement already satisfied: jupyter-core in c:\users\user\appdata\roaming\python\python310\site-packages (from nbformat>=4.2.0->ipywidgets<8.0,>=7.5->dataprep) (4.11.1)
# Requirement already satisfied: jsonschema>=2.6 in e:\anaconda\anaconda de nuevo\lib\site-packages (from nbformat>=4.2.0->ipywidgets<8.0,>=7.5->dataprep) (4.17.3)
# Requirement already satisfied: locket in e:\anaconda\anaconda de nuevo\lib\site-packages (from partd>=0.3.10->dask[array,dataframe,delayed]>=2022.3.0->dataprep) (1.0.0)
# Requirement already satisfied: notebook>=4.4.1 in e:\anaconda\anaconda de nuevo\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (6.5.2)
# Requirement already satisfied: idna>=2.0 in e:\anaconda\anaconda de nuevo\lib\site-packages (from yarl<2.0,>=1.0->aiohttp<4.0,>=3.6->dataprep) (3.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in e:\anaconda\anaconda de nuevo\lib\site-packages (from matplotlib->wordcloud<2.0,>=1.8->dataprep) (1.4.4)
# Requirement already satisfied: fonttools>=4.22.0 in e:\anaconda\anaconda de nuevo\lib\site-packages (from matplotlib->wordcloud<2.0,>=1.8->dataprep) (4.25.0)
# Requirement already satisfied: contourpy>=1.0.1 in e:\anaconda\anaconda de nuevo\lib\site-packages (from matplotlib->wordcloud<2.0,>=1.8->dataprep) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in e:\anaconda\anaconda de nuevo\lib\site-packages (from matplotlib->wordcloud<2.0,>=1.8->dataprep) (0.11.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\user\appdata\roaming\python\python310\site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets<8.0,>=7.5->dataprep) (0.8.3)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in e:\anaconda\anaconda de nuevo\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets<8.0,>=7.5->dataprep) (0.18.0)
# Requirement already satisfied: entrypoints in c:\users\user\appdata\roaming\python\python310\site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets<8.0,>=7.5->dataprep) (0.4)
# Requirement already satisfied: pywin32>=1.0 in c:\users\user\appdata\roaming\python\python310\site-packages (from jupyter-core->nbformat>=4.2.0->ipywidgets<8.0,>=7.5->dataprep) (304)
# Requirement already satisfied: argon2-cffi in e:\anaconda\anaconda de nuevo\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (21.3.0)
# Requirement already satisfied: nbconvert>=5 in e:\anaconda\anaconda de nuevo\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (6.5.4)
# Requirement already satisfied: terminado>=0.8.3 in e:\anaconda\anaconda de nuevo\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (0.17.1)
# Requirement already satisfied: nbclassic>=0.4.7 in e:\anaconda\anaconda de nuevo\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (0.5.2)
# Requirement already satisfied: Send2Trash>=1.8.0 in e:\anaconda\anaconda de nuevo\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (1.8.0)
# Requirement already satisfied: prometheus-client in e:\anaconda\anaconda de nuevo\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (0.14.1)
# Requirement already satisfied: wcwidth in c:\users\user\appdata\roaming\python\python310\site-packages (from prompt-toolkit<3.1.0,>3.0.1->ipython>=4.0.0->ipywidgets<8.0,>=7.5->dataprep) (0.2.5)
# Requirement already satisfied: notebook-shim>=0.1.0 in e:\anaconda\anaconda de nuevo\lib\site-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (0.2.2)
# Requirement already satisfied: jupyter-server>=1.8 in e:\anaconda\anaconda de nuevo\lib\site-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (1.23.4)
# Requirement already satisfied: nbclient>=0.5.0 in e:\anaconda\anaconda de nuevo\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (0.5.13)
# Requirement already satisfied: tinycss2 in e:\anaconda\anaconda de nuevo\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (1.2.1)
# Requirement already satisfied: beautifulsoup4 in e:\anaconda\anaconda de nuevo\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (4.11.1)
# Requirement already satisfied: defusedxml in e:\anaconda\anaconda de nuevo\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (0.7.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in e:\anaconda\anaconda de nuevo\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (0.8.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in e:\anaconda\anaconda de nuevo\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (1.5.0)
# Requirement already satisfied: jupyterlab-pygments in e:\anaconda\anaconda de nuevo\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (0.1.2)
# Requirement already satisfied: lxml in e:\anaconda\anaconda de nuevo\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (4.9.1)
# Requirement already satisfied: bleach in e:\anaconda\anaconda de nuevo\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (4.1.0)
# Requirement already satisfied: pywinpty>=1.1.0 in e:\anaconda\anaconda de nuevo\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (2.0.10)
# Requirement already satisfied: argon2-cffi-bindings in e:\anaconda\anaconda de nuevo\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (21.2.0)
# Requirement already satisfied: anyio<4,>=3.1.0 in e:\anaconda\anaconda de nuevo\lib\site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (3.5.0)
# Requirement already satisfied: websocket-client in e:\anaconda\anaconda de nuevo\lib\site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (0.58.0)
# Requirement already satisfied: cffi>=1.0.1 in e:\anaconda\anaconda de nuevo\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in e:\anaconda\anaconda de nuevo\lib\site-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (2.3.2.post1)
# Requirement already satisfied: webencodings in e:\anaconda\anaconda de nuevo\lib\site-packages (from bleach->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (0.5.1)
# Requirement already satisfied: sniffio>=1.1 in e:\anaconda\anaconda de nuevo\lib\site-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (1.2.0)
# Requirement already satisfied: pycparser in e:\anaconda\anaconda de nuevo\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (2.21)
# Building wheels for collected packages: sqlalchemy, metaphone
#   Building wheel for sqlalchemy (setup.py): started
#   Building wheel for sqlalchemy (setup.py): finished with status 'done'
#   Created wheel for sqlalchemy: filename=SQLAlchemy-1.3.24-cp310-cp310-win_amd64.whl size=1203282 sha256=8fa02f15b78cf9ee99062710c9ad14c61d5fba942ce205d7cd531e3828a37a61
#   Stored in directory: c:\users\user\appdata\local\pip\cache\wheels\c8\47\30\58f5319511b287d4cf145aa940abec1e7824bba5bd8f4de0b3
#   Building wheel for metaphone (setup.py): started
#   Building wheel for metaphone (setup.py): finished with status 'done'
#   Created wheel for metaphone: filename=Metaphone-0.6-py3-none-any.whl size=13945 sha256=2df3b05435a77e36dc14e2c37cd8dfe20cb43f9b74fcb010671c2be4fba5c3c3
#   Stored in directory: c:\users\user\appdata\local\pip\cache\wheels\91\df\55\49d1d0c09e7262d3e6a8ff232f4fb28380426e0db4169cea36
# Successfully built sqlalchemy metaphone
# Installing collected packages: regex, python-stdnum, python-crfsuite, metaphone, executing, sqlalchemy, rapidfuzz, pydot, pydantic, multidict, jsonpath-ng, jinja2, frozenlist, async-timeout, yarl, varname, aiosignal, wordcloud, flask_cors, aiohttp, dataprep
#   Attempting uninstall: regex
#     Found existing installation: regex 2022.7.9
#     Uninstalling regex-2022.7.9:
#       Successfully uninstalled regex-2022.7.9
#   Attempting uninstall: executing
#     Found existing installation: executing 1.0.0
#     Uninstalling executing-1.0.0:
#       Successfully uninstalled executing-1.0.0
#   Attempting uninstall: sqlalchemy
#     Found existing installation: SQLAlchemy 1.4.39
#     Uninstalling SQLAlchemy-1.4.39:
#       Successfully uninstalled SQLAlchemy-1.4.39
#   Attempting uninstall: jinja2
#     Found existing installation: Jinja2 3.1.2
#     Uninstalling Jinja2-3.1.2:
#       Successfully uninstalled Jinja2-3.1.2
# Successfully installed aiohttp-3.8.4 aiosignal-1.3.1 async-timeout-4.0.2 dataprep-0.4.5 executing-0.8.3 flask_cors-3.0.10 frozenlist-1.3.3 jinja2-3.0.3 jsonpath-ng-1.5.3 metaphone-0.6 multidict-6.0.4 pydantic-1.10.9 pydot-1.4.2 python-crfsuite-0.9.8 python-stdnum-1.18 rapidfuzz-2.15.1 regex-2021.11.10 sqlalchemy-1.3.24 varname-0.8.3 wordcloud-1.9.2 yarl-1.9.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# spyder-kernels 2.4.1 requires ipykernel<7,>=6.16.1; python_version >= "3", but you have ipykernel 6.15.3 which is incompatible.
# jupyter-console 6.6.2 requires jupyter-core!=5.0.*,>=4.12, but you have jupyter-core 4.11.1 which is incompatible.
# distributed 2022.7.0 requires tornado<6.2,>=6.0.3, but you have tornado 6.2 which is incompatible.

# %%
pip install --upgrade ipykernel
# Out:
# Requirement already satisfied: ipykernel in c:\users\user\appdata\roaming\python\python310\site-packages (6.15.3)Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not install packages due to an OSError: [WinError 5] Acceso denegado: 'C:\\Users\\user\\AppData\\Roaming\\Python\\Python310\\site-packages\\~ebugpy\\_vendored\\pydevd\\_pydevd_bundle\\pydevd_cython.cp310-win_amd64.pyd'
# Consider using the `--user` option or check the permissions.
# Collecting ipykernel
#   Downloading ipykernel-6.23.2-py3-none-any.whl (152 kB)
#      -------------------------------------- 152.8/152.8 kB 8.9 MB/s eta 0:00:00
# Requirement already satisfied: traitlets>=5.4.0 in c:\users\user\appdata\roaming\python\python310\site-packages (from ipykernel) (5.4.0)
# Requirement already satisfied: tornado>=6.1 in c:\users\user\appdata\roaming\python\python310\site-packages (from ipykernel) (6.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\user\appdata\roaming\python\python310\site-packages (from ipykernel) (0.1.6)
# Requirement already satisfied: comm>=0.1.1 in e:\anaconda\anaconda de nuevo\lib\site-packages (from ipykernel) (0.1.2)
# Collecting jupyter-core!=5.0.*,>=4.12
#   Downloading jupyter_core-5.3.1-py3-none-any.whl (93 kB)
#      ---------------------------------------- 93.7/93.7 kB 5.2 MB/s eta 0:00:00
# Requirement already satisfied: packaging in c:\users\user\appdata\roaming\python\python310\site-packages (from ipykernel) (21.3)
# Requirement already satisfied: psutil in c:\users\user\appdata\roaming\python\python310\site-packages (from ipykernel) (5.9.2)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\user\appdata\roaming\python\python310\site-packages (from ipykernel) (8.5.0)
# Collecting debugpy>=1.6.5
#   Downloading debugpy-1.6.7-cp310-cp310-win_amd64.whl (4.8 MB)
#      ---------------------------------------- 4.8/4.8 MB 8.3 MB/s eta 0:00:00
# Requirement already satisfied: nest-asyncio in c:\users\user\appdata\roaming\python\python310\site-packages (from ipykernel) (1.5.5)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\user\appdata\roaming\python\python310\site-packages (from ipykernel) (7.3.5)
# Requirement already satisfied: pyzmq>=20 in c:\users\user\appdata\roaming\python\python310\site-packages (from ipykernel) (24.0.1)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\user\appdata\roaming\python\python310\site-packages (from ipython>=7.23.1->ipykernel) (2.13.0)
# Requirement already satisfied: stack-data in c:\users\user\appdata\roaming\python\python310\site-packages (from ipython>=7.23.1->ipykernel) (0.5.0)
# Requirement already satisfied: pickleshare in c:\users\user\appdata\roaming\python\python310\site-packages (from ipython>=7.23.1->ipykernel) (0.7.5)
# Requirement already satisfied: backcall in c:\users\user\appdata\roaming\python\python310\site-packages (from ipython>=7.23.1->ipykernel) (0.2.0)
# Requirement already satisfied: prompt-toolkit<3.1.0,>3.0.1 in c:\users\user\appdata\roaming\python\python310\site-packages (from ipython>=7.23.1->ipykernel) (3.0.31)
# Requirement already satisfied: jedi>=0.16 in c:\users\user\appdata\roaming\python\python310\site-packages (from ipython>=7.23.1->ipykernel) (0.18.1)
# Requirement already satisfied: decorator in c:\users\user\appdata\roaming\python\python310\site-packages (from ipython>=7.23.1->ipykernel) (5.1.1)
# Requirement already satisfied: colorama in c:\users\user\appdata\roaming\python\python310\site-packages (from ipython>=7.23.1->ipykernel) (0.4.5)
# Requirement already satisfied: entrypoints in c:\users\user\appdata\roaming\python\python310\site-packages (from jupyter-client>=6.1.12->ipykernel) (0.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\user\appdata\roaming\python\python310\site-packages (from jupyter-client>=6.1.12->ipykernel) (2.8.2)
# Requirement already satisfied: pywin32>=300 in c:\users\user\appdata\roaming\python\python310\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel) (304)
# Requirement already satisfied: platformdirs>=2.5 in e:\anaconda\anaconda de nuevo\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel) (2.5.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\user\appdata\roaming\python\python310\site-packages (from packaging->ipykernel) (3.0.9)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\user\appdata\roaming\python\python310\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel) (0.8.3)
# Requirement already satisfied: wcwidth in c:\users\user\appdata\roaming\python\python310\site-packages (from prompt-toolkit<3.1.0,>3.0.1->ipython>=7.23.1->ipykernel) (0.2.5)
# Requirement already satisfied: six>=1.5 in c:\users\user\appdata\roaming\python\python310\site-packages (from python-dateutil>=2.8.2->jupyter-client>=6.1.12->ipykernel) (1.16.0)
# Requirement already satisfied: pure-eval in c:\users\user\appdata\roaming\python\python310\site-packages (from stack-data->ipython>=7.23.1->ipykernel) (0.2.2)
# Requirement already satisfied: executing in e:\anaconda\anaconda de nuevo\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\user\appdata\roaming\python\python310\site-packages (from stack-data->ipython>=7.23.1->ipykernel) (2.0.8)
# Installing collected packages: jupyter-core, debugpy, ipykernel
#   Attempting uninstall: jupyter-core
#     Found existing installation: jupyter-core 4.11.1
#     Uninstalling jupyter-core-4.11.1:
#       Successfully uninstalled jupyter-core-4.11.1
#   Attempting uninstall: debugpy
#     Found existing installation: debugpy 1.6.3
#     Uninstalling debugpy-1.6.3:
#       Successfully uninstalled debugpy-1.6.3

# %%
pip install --upgrade ipykernel --user
# Out:
# Requirement already satisfied: ipykernel in c:\users\user\appdata\roaming\python\python310\site-packages (6.15.3)Note: you may need to restart the kernel to use updated packages.
#
# Collecting ipykernel
#   Using cached ipykernel-6.23.2-py3-none-any.whl (152 kB)
# Requirement already satisfied: tornado>=6.1 in c:\users\user\appdata\roaming\python\python310\site-packages (from ipykernel) (6.2)
# Requirement already satisfied: pyzmq>=20 in c:\users\user\appdata\roaming\python\python310\site-packages (from ipykernel) (24.0.1)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\user\appdata\roaming\python\python310\site-packages (from ipykernel) (8.5.0)
# Requirement already satisfied: comm>=0.1.1 in e:\anaconda\anaconda de nuevo\lib\site-packages (from ipykernel) (0.1.2)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in e:\anaconda\anaconda de nuevo\lib\site-packages (from ipykernel) (5.3.1)
# Requirement already satisfied: traitlets>=5.4.0 in c:\users\user\appdata\roaming\python\python310\site-packages (from ipykernel) (5.4.0)
# Requirement already satisfied: packaging in c:\users\user\appdata\roaming\python\python310\site-packages (from ipykernel) (21.3)
# Requirement already satisfied: psutil in c:\users\user\appdata\roaming\python\python310\site-packages (from ipykernel) (5.9.2)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\user\appdata\roaming\python\python310\site-packages (from ipykernel) (7.3.5)
# Requirement already satisfied: debugpy>=1.6.5 in e:\anaconda\anaconda de nuevo\lib\site-packages (from ipykernel) (1.6.7)
# Requirement already satisfied: nest-asyncio in c:\users\user\appdata\roaming\python\python310\site-packages (from ipykernel) (1.5.5)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\user\appdata\roaming\python\python310\site-packages (from ipykernel) (0.1.6)
# Requirement already satisfied: pickleshare in c:\users\user\appdata\roaming\python\python310\site-packages (from ipython>=7.23.1->ipykernel) (0.7.5)
# Requirement already satisfied: backcall in c:\users\user\appdata\roaming\python\python310\site-packages (from ipython>=7.23.1->ipykernel) (0.2.0)
# Requirement already satisfied: prompt-toolkit<3.1.0,>3.0.1 in c:\users\user\appdata\roaming\python\python310\site-packages (from ipython>=7.23.1->ipykernel) (3.0.31)
# Requirement already satisfied: colorama in c:\users\user\appdata\roaming\python\python310\site-packages (from ipython>=7.23.1->ipykernel) (0.4.5)
# Requirement already satisfied: decorator in c:\users\user\appdata\roaming\python\python310\site-packages (from ipython>=7.23.1->ipykernel) (5.1.1)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\user\appdata\roaming\python\python310\site-packages (from ipython>=7.23.1->ipykernel) (2.13.0)
# Requirement already satisfied: stack-data in c:\users\user\appdata\roaming\python\python310\site-packages (from ipython>=7.23.1->ipykernel) (0.5.0)
# Requirement already satisfied: jedi>=0.16 in c:\users\user\appdata\roaming\python\python310\site-packages (from ipython>=7.23.1->ipykernel) (0.18.1)
# Requirement already satisfied: entrypoints in c:\users\user\appdata\roaming\python\python310\site-packages (from jupyter-client>=6.1.12->ipykernel) (0.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\user\appdata\roaming\python\python310\site-packages (from jupyter-client>=6.1.12->ipykernel) (2.8.2)
# Requirement already satisfied: pywin32>=300 in c:\users\user\appdata\roaming\python\python310\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel) (304)
# Requirement already satisfied: platformdirs>=2.5 in e:\anaconda\anaconda de nuevo\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel) (2.5.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\user\appdata\roaming\python\python310\site-packages (from packaging->ipykernel) (3.0.9)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\user\appdata\roaming\python\python310\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel) (0.8.3)
# Requirement already satisfied: wcwidth in c:\users\user\appdata\roaming\python\python310\site-packages (from prompt-toolkit<3.1.0,>3.0.1->ipython>=7.23.1->ipykernel) (0.2.5)
# Requirement already satisfied: six>=1.5 in c:\users\user\appdata\roaming\python\python310\site-packages (from python-dateutil>=2.8.2->jupyter-client>=6.1.12->ipykernel) (1.16.0)
# Requirement already satisfied: asttokens in c:\users\user\appdata\roaming\python\python310\site-packages (from stack-data->ipython>=7.23.1->ipykernel) (2.0.8)
# Requirement already satisfied: pure-eval in c:\users\user\appdata\roaming\python\python310\site-packages (from stack-data->ipython>=7.23.1->ipykernel) (0.2.2)
# Requirement already satisfied: executing in e:\anaconda\anaconda de nuevo\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel) (0.8.3)
# Installing collected packages: ipykernel
#   Attempting uninstall: ipykernel
#     Found existing installation: ipykernel 6.15.3
#     Uninstalling ipykernel-6.15.3:
#       Successfully uninstalled ipykernel-6.15.3
# Successfully installed ipykernel-6.23.2

# %%
pip install -U dataprep
# Out:
# Requirement already satisfied: dataprep in e:\anaconda\anaconda de nuevo\lib\site-packages (0.4.5)
# Requirement already satisfied: aiohttp<4.0,>=3.6 in e:\anaconda\anaconda de nuevo\lib\site-packages (from dataprep) (3.8.4)
# Requirement already satisfied: pydot<2.0.0,>=1.4.2 in e:\anaconda\anaconda de nuevo\lib\site-packages (from dataprep) (1.4.2)
# Requirement already satisfied: regex<2022.0.0,>=2021.8.3 in e:\anaconda\anaconda de nuevo\lib\site-packages (from dataprep) (2021.11.10)
# Requirement already satisfied: jinja2<3.1,>=3.0 in e:\anaconda\anaconda de nuevo\lib\site-packages (from dataprep) (3.0.3)
# Requirement already satisfied: pandas<2.0,>=1.1 in e:\anaconda\anaconda de nuevo\lib\site-packages (from dataprep) (1.5.3)
# Requirement already satisfied: tqdm<5.0,>=4.48 in e:\anaconda\anaconda de nuevo\lib\site-packages (from dataprep) (4.64.1)
# Requirement already satisfied: nltk<4.0.0,>=3.6.7 in e:\anaconda\anaconda de nuevo\lib\site-packages (from dataprep) (3.7)
# Requirement already satisfied: ipywidgets<8.0,>=7.5 in e:\anaconda\anaconda de nuevo\lib\site-packages (from dataprep) (7.6.5)
# Requirement already satisfied: dask[array,dataframe,delayed]>=2022.3.0 in e:\anaconda\anaconda de nuevo\lib\site-packages (from dataprep) (2022.7.0)
# Requirement already satisfied: scipy<2.0,>=1.8 in e:\anaconda\anaconda de nuevo\lib\site-packages (from dataprep) (1.10.0)
# Requirement already satisfied: bokeh<3,>=2 in e:\anaconda\anaconda de nuevo\lib\site-packages (from dataprep) (2.4.3)
# Requirement already satisfied: flask<3,>=2 in e:\anaconda\anaconda de nuevo\lib\site-packages (from dataprep) (2.2.2)
# Requirement already satisfied: python-crfsuite==0.9.8 in e:\anaconda\anaconda de nuevo\lib\site-packages (from dataprep) (0.9.8)
# Requirement already satisfied: pydantic<2.0,>=1.6 in e:\anaconda\anaconda de nuevo\lib\site-packages (from dataprep) (1.10.9)
# Requirement already satisfied: sqlalchemy==1.3.24 in e:\anaconda\anaconda de nuevo\lib\site-packages (from dataprep) (1.3.24)
# Requirement already satisfied: jsonpath-ng<2.0,>=1.5 in e:\anaconda\anaconda de nuevo\lib\site-packages (from dataprep) (1.5.3)
# Requirement already satisfied: python-stdnum<2.0,>=1.16 in e:\anaconda\anaconda de nuevo\lib\site-packages (from dataprep) (1.18)
# Requirement already satisfied: wordcloud<2.0,>=1.8 in e:\anaconda\anaconda de nuevo\lib\site-packages (from dataprep) (1.9.2)
# Requirement already satisfied: varname<0.9.0,>=0.8.1 in e:\anaconda\anaconda de nuevo\lib\site-packages (from dataprep) (0.8.3)
# Requirement already satisfied: numpy<2.0,>=1.21 in e:\anaconda\anaconda de nuevo\lib\site-packages (from dataprep) (1.23.5)
# Requirement already satisfied: flask_cors<4.0.0,>=3.0.10 in e:\anaconda\anaconda de nuevo\lib\site-packages (from dataprep) (3.0.10)
# Requirement already satisfied: rapidfuzz<3.0.0,>=2.1.2 in e:\anaconda\anaconda de nuevo\lib\site-packages (from dataprep) (2.15.1)
# Requirement already satisfied: metaphone<0.7,>=0.6 in e:\anaconda\anaconda de nuevo\lib\site-packages (from dataprep) (0.6)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in e:\anaconda\anaconda de nuevo\lib\site-packages (from aiohttp<4.0,>=3.6->dataprep) (2.0.4)
# Requirement already satisfied: multidict<7.0,>=4.5 in e:\anaconda\anaconda de nuevo\lib\site-packages (from aiohttp<4.0,>=3.6->dataprep) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in e:\anaconda\anaconda de nuevo\lib\site-packages (from aiohttp<4.0,>=3.6->dataprep) (4.0.2)
# Requirement already satisfied: attrs>=17.3.0 in e:\anaconda\anaconda de nuevo\lib\site-packages (from aiohttp<4.0,>=3.6->dataprep) (22.1.0)
# Requirement already satisfied: aiosignal>=1.1.2 in e:\anaconda\anaconda de nuevo\lib\site-packages (from aiohttp<4.0,>=3.6->dataprep) (1.3.1)
# Requirement already satisfied: frozenlist>=1.1.1 in e:\anaconda\anaconda de nuevo\lib\site-packages (from aiohttp<4.0,>=3.6->dataprep) (1.3.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in e:\anaconda\anaconda de nuevo\lib\site-packages (from aiohttp<4.0,>=3.6->dataprep) (1.9.2)
# Requirement already satisfied: tornado>=5.1 in c:\users\user\appdata\roaming\python\python310\site-packages (from bokeh<3,>=2->dataprep) (6.2)
# Requirement already satisfied: typing-extensions>=3.10.0 in e:\anaconda\anaconda de nuevo\lib\site-packages (from bokeh<3,>=2->dataprep) (4.4.0)
# Requirement already satisfied: packaging>=16.8 in c:\users\user\appdata\roaming\python\python310\site-packages (from bokeh<3,>=2->dataprep) (21.3)
# Requirement already satisfied: pillow>=7.1.0 in e:\anaconda\anaconda de nuevo\lib\site-packages (from bokeh<3,>=2->dataprep) (9.4.0)
# Requirement already satisfied: PyYAML>=3.10 in e:\anaconda\anaconda de nuevo\lib\site-packages (from bokeh<3,>=2->dataprep) (6.0)
# Requirement already satisfied: partd>=0.3.10 in e:\anaconda\anaconda de nuevo\lib\site-packages (from dask[array,dataframe,delayed]>=2022.3.0->dataprep) (1.2.0)
# Requirement already satisfied: cloudpickle>=1.1.1 in e:\anaconda\anaconda de nuevo\lib\site-packages (from dask[array,dataframe,delayed]>=2022.3.0->dataprep) (2.0.0)
# Requirement already satisfied: toolz>=0.8.2 in e:\anaconda\anaconda de nuevo\lib\site-packages (from dask[array,dataframe,delayed]>=2022.3.0->dataprep) (0.12.0)
# Requirement already satisfied: fsspec>=0.6.0 in e:\anaconda\anaconda de nuevo\lib\site-packages (from dask[array,dataframe,delayed]>=2022.3.0->dataprep) (2022.11.0)
# Requirement already satisfied: Werkzeug>=2.2.2 in e:\anaconda\anaconda de nuevo\lib\site-packages (from flask<3,>=2->dataprep) (2.2.2)
# Requirement already satisfied: click>=8.0 in e:\anaconda\anaconda de nuevo\lib\site-packages (from flask<3,>=2->dataprep) (8.0.4)
# Requirement already satisfied: itsdangerous>=2.0 in e:\anaconda\anaconda de nuevo\lib\site-packages (from flask<3,>=2->dataprep) (2.0.1)
# Requirement already satisfied: Six in c:\users\user\appdata\roaming\python\python310\site-packages (from flask_cors<4.0.0,>=3.0.10->dataprep) (1.16.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\user\appdata\roaming\python\python310\site-packages (from ipywidgets<8.0,>=7.5->dataprep) (5.4.0)
# Requirement already satisfied: ipython-genutils~=0.2.0 in e:\anaconda\anaconda de nuevo\lib\site-packages (from ipywidgets<8.0,>=7.5->dataprep) (0.2.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in e:\anaconda\anaconda de nuevo\lib\site-packages (from ipywidgets<8.0,>=7.5->dataprep) (3.5.2)
# Requirement already satisfied: nbformat>=4.2.0 in e:\anaconda\anaconda de nuevo\lib\site-packages (from ipywidgets<8.0,>=7.5->dataprep) (5.7.0)
# Requirement already satisfied: ipython>=4.0.0 in c:\users\user\appdata\roaming\python\python310\site-packages (from ipywidgets<8.0,>=7.5->dataprep) (8.5.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in e:\anaconda\anaconda de nuevo\lib\site-packages (from ipywidgets<8.0,>=7.5->dataprep) (1.0.0)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\user\appdata\roaming\python\python310\site-packages (from ipywidgets<8.0,>=7.5->dataprep) (6.23.2)
# Requirement already satisfied: MarkupSafe>=2.0 in e:\anaconda\anaconda de nuevo\lib\site-packages (from jinja2<3.1,>=3.0->dataprep) (2.1.1)
# Requirement already satisfied: ply in e:\anaconda\anaconda de nuevo\lib\site-packages (from jsonpath-ng<2.0,>=1.5->dataprep) (3.11)
# Requirement already satisfied: decorator in c:\users\user\appdata\roaming\python\python310\site-packages (from jsonpath-ng<2.0,>=1.5->dataprep) (5.1.1)
# Requirement already satisfied: joblib in e:\anaconda\anaconda de nuevo\lib\site-packages (from nltk<4.0.0,>=3.6.7->dataprep) (1.1.1)
# Requirement already satisfied: pytz>=2020.1 in e:\anaconda\anaconda de nuevo\lib\site-packages (from pandas<2.0,>=1.1->dataprep) (2022.7)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\user\appdata\roaming\python\python310\site-packages (from pandas<2.0,>=1.1->dataprep) (2.8.2)
# Requirement already satisfied: pyparsing>=2.1.4 in c:\users\user\appdata\roaming\python\python310\site-packages (from pydot<2.0.0,>=1.4.2->dataprep) (3.0.9)
# Requirement already satisfied: colorama in c:\users\user\appdata\roaming\python\python310\site-packages (from tqdm<5.0,>=4.48->dataprep) (0.4.5)
# Requirement already satisfied: pure_eval<1.0.0 in c:\users\user\appdata\roaming\python\python310\site-packages (from varname<0.9.0,>=0.8.1->dataprep) (0.2.2)
# Requirement already satisfied: executing<0.9.0,>=0.8.3 in e:\anaconda\anaconda de nuevo\lib\site-packages (from varname<0.9.0,>=0.8.1->dataprep) (0.8.3)
# Requirement already satisfied: asttokens<3.0.0,>=2.0.0 in c:\users\user\appdata\roaming\python\python310\site-packages (from varname<0.9.0,>=0.8.1->dataprep) (2.0.8)
# Requirement already satisfied: matplotlib in e:\anaconda\anaconda de nuevo\lib\site-packages (from wordcloud<2.0,>=1.8->dataprep) (3.7.0)
# Requirement already satisfied: pyzmq>=20 in c:\users\user\appdata\roaming\python\python310\site-packages (from ipykernel>=4.5.1->ipywidgets<8.0,>=7.5->dataprep) (24.0.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\user\appdata\roaming\python\python310\site-packages (from ipykernel>=4.5.1->ipywidgets<8.0,>=7.5->dataprep) (0.1.6)
# Requirement already satisfied: debugpy>=1.6.5 in e:\anaconda\anaconda de nuevo\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<8.0,>=7.5->dataprep) (1.6.7)
# Requirement already satisfied: psutil in c:\users\user\appdata\roaming\python\python310\site-packages (from ipykernel>=4.5.1->ipywidgets<8.0,>=7.5->dataprep) (5.9.2)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in e:\anaconda\anaconda de nuevo\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<8.0,>=7.5->dataprep) (5.3.1)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\user\appdata\roaming\python\python310\site-packages (from ipykernel>=4.5.1->ipywidgets<8.0,>=7.5->dataprep) (7.3.5)
# Requirement already satisfied: comm>=0.1.1 in e:\anaconda\anaconda de nuevo\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<8.0,>=7.5->dataprep) (0.1.2)
# Requirement already satisfied: nest-asyncio in c:\users\user\appdata\roaming\python\python310\site-packages (from ipykernel>=4.5.1->ipywidgets<8.0,>=7.5->dataprep) (1.5.5)
# Requirement already satisfied: jedi>=0.16 in c:\users\user\appdata\roaming\python\python310\site-packages (from ipython>=4.0.0->ipywidgets<8.0,>=7.5->dataprep) (0.18.1)
# Requirement already satisfied: stack-data in c:\users\user\appdata\roaming\python\python310\site-packages (from ipython>=4.0.0->ipywidgets<8.0,>=7.5->dataprep) (0.5.0)
# Requirement already satisfied: backcall in c:\users\user\appdata\roaming\python\python310\site-packages (from ipython>=4.0.0->ipywidgets<8.0,>=7.5->dataprep) (0.2.0)
# Requirement already satisfied: pickleshare in c:\users\user\appdata\roaming\python\python310\site-packages (from ipython>=4.0.0->ipywidgets<8.0,>=7.5->dataprep) (0.7.5)
# Requirement already satisfied: prompt-toolkit<3.1.0,>3.0.1 in c:\users\user\appdata\roaming\python\python310\site-packages (from ipython>=4.0.0->ipywidgets<8.0,>=7.5->dataprep) (3.0.31)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\user\appdata\roaming\python\python310\site-packages (from ipython>=4.0.0->ipywidgets<8.0,>=7.5->dataprep) (2.13.0)
# Requirement already satisfied: jsonschema>=2.6 in e:\anaconda\anaconda de nuevo\lib\site-packages (from nbformat>=4.2.0->ipywidgets<8.0,>=7.5->dataprep) (4.17.3)
# Requirement already satisfied: fastjsonschema in e:\anaconda\anaconda de nuevo\lib\site-packages (from nbformat>=4.2.0->ipywidgets<8.0,>=7.5->dataprep) (2.16.2)
# Requirement already satisfied: locket in e:\anaconda\anaconda de nuevo\lib\site-packages (from partd>=0.3.10->dask[array,dataframe,delayed]>=2022.3.0->dataprep) (1.0.0)
# Requirement already satisfied: notebook>=4.4.1 in e:\anaconda\anaconda de nuevo\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (6.5.2)
# Requirement already satisfied: idna>=2.0 in e:\anaconda\anaconda de nuevo\lib\site-packages (from yarl<2.0,>=1.0->aiohttp<4.0,>=3.6->dataprep) (3.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in e:\anaconda\anaconda de nuevo\lib\site-packages (from matplotlib->wordcloud<2.0,>=1.8->dataprep) (1.4.4)
# Requirement already satisfied: contourpy>=1.0.1 in e:\anaconda\anaconda de nuevo\lib\site-packages (from matplotlib->wordcloud<2.0,>=1.8->dataprep) (1.0.5)
# Requirement already satisfied: fonttools>=4.22.0 in e:\anaconda\anaconda de nuevo\lib\site-packages (from matplotlib->wordcloud<2.0,>=1.8->dataprep) (4.25.0)
# Requirement already satisfied: cycler>=0.10 in e:\anaconda\anaconda de nuevo\lib\site-packages (from matplotlib->wordcloud<2.0,>=1.8->dataprep) (0.11.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\user\appdata\roaming\python\python310\site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets<8.0,>=7.5->dataprep) (0.8.3)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in e:\anaconda\anaconda de nuevo\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets<8.0,>=7.5->dataprep) (0.18.0)
# Requirement already satisfied: entrypoints in c:\users\user\appdata\roaming\python\python310\site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets<8.0,>=7.5->dataprep) (0.4)
# Requirement already satisfied: pywin32>=300 in c:\users\user\appdata\roaming\python\python310\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=4.5.1->ipywidgets<8.0,>=7.5->dataprep) (304)
# Requirement already satisfied: platformdirs>=2.5 in e:\anaconda\anaconda de nuevo\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=4.5.1->ipywidgets<8.0,>=7.5->dataprep) (2.5.2)
# Requirement already satisfied: terminado>=0.8.3 in e:\anaconda\anaconda de nuevo\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (0.17.1)
# Requirement already satisfied: prometheus-client in e:\anaconda\anaconda de nuevo\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (0.14.1)
# Requirement already satisfied: nbclassic>=0.4.7 in e:\anaconda\anaconda de nuevo\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (0.5.2)
# Requirement already satisfied: nbconvert>=5 in e:\anaconda\anaconda de nuevo\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (6.5.4)
# Requirement already satisfied: argon2-cffi in e:\anaconda\anaconda de nuevo\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (21.3.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in e:\anaconda\anaconda de nuevo\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (1.8.0)
# Requirement already satisfied: wcwidth in c:\users\user\appdata\roaming\python\python310\site-packages (from prompt-toolkit<3.1.0,>3.0.1->ipython>=4.0.0->ipywidgets<8.0,>=7.5->dataprep) (0.2.5)
# Requirement already satisfied: notebook-shim>=0.1.0 in e:\anaconda\anaconda de nuevo\lib\site-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (0.2.2)
# Requirement already satisfied: jupyter-server>=1.8 in e:\anaconda\anaconda de nuevo\lib\site-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (1.23.4)
# Requirement already satisfied: lxml in e:\anaconda\anaconda de nuevo\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (4.9.1)
# Requirement already satisfied: beautifulsoup4 in e:\anaconda\anaconda de nuevo\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (4.11.1)
# Requirement already satisfied: bleach in e:\anaconda\anaconda de nuevo\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (4.1.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in e:\anaconda\anaconda de nuevo\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (1.5.0)
# Requirement already satisfied: tinycss2 in e:\anaconda\anaconda de nuevo\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (1.2.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in e:\anaconda\anaconda de nuevo\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (0.8.4)
# Requirement already satisfied: nbclient>=0.5.0 in e:\anaconda\anaconda de nuevo\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (0.5.13)
# Requirement already satisfied: defusedxml in e:\anaconda\anaconda de nuevo\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in e:\anaconda\anaconda de nuevo\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (0.1.2)
# Requirement already satisfied: pywinpty>=1.1.0 in e:\anaconda\anaconda de nuevo\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (2.0.10)
# Requirement already satisfied: argon2-cffi-bindings in e:\anaconda\anaconda de nuevo\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (21.2.0)
# Requirement already satisfied: anyio<4,>=3.1.0 in e:\anaconda\anaconda de nuevo\lib\site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (3.5.0)
# Requirement already satisfied: websocket-client in e:\anaconda\anaconda de nuevo\lib\site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (0.58.0)
# Requirement already satisfied: cffi>=1.0.1 in e:\anaconda\anaconda de nuevo\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in e:\anaconda\anaconda de nuevo\lib\site-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (2.3.2.post1)
# Requirement already satisfied: webencodings in e:\anaconda\anaconda de nuevo\lib\site-packages (from bleach->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (0.5.1)
# Requirement already satisfied: sniffio>=1.1 in e:\anaconda\anaconda de nuevo\lib\site-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (1.2.0)
# Requirement already satisfied: pycparser in e:\anaconda\anaconda de nuevo\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8.0,>=7.5->dataprep) (2.21)
# Note: you may need to restart the kernel to use updated packages.
