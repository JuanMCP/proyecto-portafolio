# %%
import pandas as pd

# %%
pd.read_csv('E:\Github Desktop\proyecto-portafolio\data\Data Science Salary\ds_salaries.csv')
# Out:
#       work_year experience_level employment_type                 job_title  \
# 0          2023               SE              FT  Principal Data Scientist
# 1          2023               MI              CT               ML Engineer
# 2          2023               MI              CT               ML Engineer
# 3          2023               SE              FT            Data Scientist
# 4          2023               SE              FT            Data Scientist
# ...         ...              ...             ...                       ...
# 3750       2020               SE              FT            Data Scientist
# 3751       2021               MI              FT  Principal Data Scientist
# 3752       2020               EN              FT            Data Scientist
# 3753       2020               EN              CT     Business Data Analyst
# 3754       2021               SE              FT      Data Science Manager
#
# ...

# %%
pd.read_csv('E:\Github Desktop\proyecto-portafolio\data\Data Science Salary\ds_salaries2.csv')
# Out:
#      Unnamed: 0  work_year experience_level employment_type  \
# 0             0       2020               MI              FT
# 1             1       2020               SE              FT
# 2             2       2020               SE              FT
# 3             3       2020               MI              FT
# 4             4       2020               SE              FT
# ..          ...        ...              ...             ...
# 602         602       2022               SE              FT
# 603         603       2022               SE              FT
# 604         604       2022               SE              FT
# 605         605       2022               SE              FT
# 606         606       2022               MI              FT
#
#                       job_title  salary salary_currency  salary_in_usd  \
# 0                Data Scientist   70000             EUR          79833
# 1    Machine Learning Scientist  260000             USD         260000
# ...

# %%
df=pd.read_csv('E:\Github Desktop\proyecto-portafolio\data\Data Science Salary\ds_salaries2.csv')

# %%
# Elimina la columna 'Unnamed: 0'
df = df.drop('Unnamed: 0', axis=1)

# %%
df
# Out:
#      work_year experience_level employment_type                   job_title  \
# 0         2020               MI              FT              Data Scientist
# 1         2020               SE              FT  Machine Learning Scientist
# 2         2020               SE              FT           Big Data Engineer
# 3         2020               MI              FT        Product Data Analyst
# 4         2020               SE              FT   Machine Learning Engineer
# ..         ...              ...             ...                         ...
# 602       2022               SE              FT               Data Engineer
# 603       2022               SE              FT               Data Engineer
# 604       2022               SE              FT                Data Analyst
# 605       2022               SE              FT                Data Analyst
# 606       2022               MI              FT                AI Scientist
#
# ...

# %%
# Guarda el dataframe actualizado en un nuevo archivo CSV
df.to_csv('E:\Github Desktop\proyecto-portafolio\data\Data Science Salary\ds_salaries2.csv', index=False)

# %%
df
# Out:
#      work_year experience_level employment_type                   job_title  \
# 0         2020               MI              FT              Data Scientist
# 1         2020               SE              FT  Machine Learning Scientist
# 2         2020               SE              FT           Big Data Engineer
# 3         2020               MI              FT        Product Data Analyst
# 4         2020               SE              FT   Machine Learning Engineer
# ..         ...              ...             ...                         ...
# 602       2022               SE              FT               Data Engineer
# 603       2022               SE              FT               Data Engineer
# 604       2022               SE              FT                Data Analyst
# 605       2022               SE              FT                Data Analyst
# 606       2022               MI              FT                AI Scientist
#
# ...

# %%
df1=pd.read_csv('E:\Github Desktop\proyecto-portafolio\data\Data Science Salary\ds_salaries.csv')

# %%
df1
# Out:
#       work_year experience_level employment_type                 job_title  \
# 0          2023               SE              FT  Principal Data Scientist
# 1          2023               MI              CT               ML Engineer
# 2          2023               MI              CT               ML Engineer
# 3          2023               SE              FT            Data Scientist
# 4          2023               SE              FT            Data Scientist
# ...         ...              ...             ...                       ...
# 3750       2020               SE              FT            Data Scientist
# 3751       2021               MI              FT  Principal Data Scientist
# 3752       2020               EN              FT            Data Scientist
# 3753       2020               EN              CT     Business Data Analyst
# 3754       2021               SE              FT      Data Science Manager
#
# ...

# %%
# Combina los dataframes
df_combinado = pd.concat([df1, df])

# Guarda el dataframe combinado en un nuevo archivo CSV
df_combinado.to_csv('ds_salaries_comb.csv', index=False)

# %%
df_combinado
# Out:
#      work_year experience_level employment_type                 job_title  \
# 0         2023               SE              FT  Principal Data Scientist
# 1         2023               MI              CT               ML Engineer
# 2         2023               MI              CT               ML Engineer
# 3         2023               SE              FT            Data Scientist
# 4         2023               SE              FT            Data Scientist
# ..         ...              ...             ...                       ...
# 602       2022               SE              FT             Data Engineer
# 603       2022               SE              FT             Data Engineer
# 604       2022               SE              FT              Data Analyst
# 605       2022               SE              FT              Data Analyst
# 606       2022               MI              FT              AI Scientist
#
#      salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# ...

# %%
# Ordena los datos por la columna 'work_year' en orden descendente
df_combinado = df.sort_values('work_year', ascending=False)

# %%
print(df_combinado)
# Out:
#      work_year experience_level employment_type       job_title  salary  \
# 303       2022               SE              FT  Data Scientist  123000
# 399       2022               SE              FT  Data Scientist  158200
# 401       2022               SE              FT   Data Engineer  154600
# 402       2022               SE              FT    Data Analyst  115934
# 403       2022               SE              FT    Data Analyst   81666
# ..         ...              ...             ...             ...     ...
# 49        2020               MI              FT   Data Engineer   61500
# 50        2020               EN              FT    Data Analyst  450000
# 51        2020               EN              FT    Data Analyst   91000
# 52        2020               EN              FT    AI Scientist  300000
# 0         2020               MI              FT  Data Scientist   70000
#
#     salary_currency  salary_in_usd employee_residence  remote_ratio  \
# ...

# %%
df = pd.read_csv('C:\\Users\\jjcpm3\\Documents\\GitHub\\proyecto-portafolio\\data\\Data Science Salary\\ds_salaries_comb.csv')

# %%
df
# Out:
#       work_year experience_level employment_type                 job_title  \
# 0          2023               SE              FT  Principal Data Scientist
# 1          2023               MI              CT               ML Engineer
# 2          2023               MI              CT               ML Engineer
# 3          2023               SE              FT            Data Scientist
# 4          2023               SE              FT            Data Scientist
# ...         ...              ...             ...                       ...
# 4357       2020               SE              FT      Data Science Manager
# 4358       2020               EN              FT            Data Scientist
# 4359       2020               SE              FT            Data Scientist
# 4360       2020               MI              FT            Data Scientist
# 4361       2020               MI              FT            Data Scientist
#
# ...

# %%
# Encuentra las filas duplicadas en función de todas las columnas
result_df = df.drop_duplicates

# Muestra el DataFrame resultante
print('Result DataFrame:\n', result_df)
# Out:
# Result DataFrame:
#  <bound method DataFrame.drop_duplicates of       work_year experience_level employment_type                 job_title  \
# 0          2023               SE              FT  Principal Data Scientist
# 1          2023               MI              CT               ML Engineer
# 2          2023               MI              CT               ML Engineer
# 3          2023               SE              FT            Data Scientist
# 4          2023               SE              FT            Data Scientist
# ...         ...              ...             ...                       ...
# 4357       2020               SE              FT      Data Science Manager
# 4358       2020               EN              FT            Data Scientist
# 4359       2020               SE              FT            Data Scientist
# 4360       2020               MI              FT            Data Scientist
# 4361       2020               MI              FT            Data Scientist
#
# ...

# %%
# Guarda el dataframe resultante en un nuevo archivo CSV
result_df.to_csv('resultado.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10524\984877286.py in <module>
#       1 # Guarda el dataframe resultante en un nuevo archivo CSV
# ----> 2 result_df.to_csv('resultado.csv', index=False)
#
# AttributeError: 'function' object has no attribute 'to_csv'
